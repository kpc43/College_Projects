# %%
from vpython import *
scene = canvas()
# Out:
# C:\Users\there\anaconda3\envs\myenv\lib\site-packages\vpython\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# <div id="glowscript" class="glowscript"></div>
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# # Sphere
# Simple Sphere

# %%
sphere()

# %% [markdown]
# # Ball Bounce of walls

# %%
scene = canvas()
ball = sphere(pos=vector(-5,0,0), radius=0.5, color=color.cyan, make_trail=True)
wallR = box(pos=vector(6,0,0), size=vector(0.2,12,12), color=color.green)
wallL = box(pos=vector(-6,0,0), size=vector(0.2,12,12), color=color.green)
wallB = box(pos=vector(0,0,-6), size=vector(12,12,0.2), color=color.red)
wallBottom = box(pos=vector(0,-6,0), size=vector(12,0.2,12), color=color.blue)
wallT = box(pos=vector(0,6,0), size=vector(12,0.2,12), color=color.blue)

ball.velocity = vector(25,5,15)
deltat = 0.005
t = 0
vscale = 0.1
varr = arrow(pos=ball.pos, axis=vscale*ball.velocity, color=color.yellow)
scene.autoscale = False

while t < 3:
    rate(100)
    
    if ball.pos.x > wallR.pos.x:
        ball.velocity.x = -ball.velocity.x
        varr.axis = vscale*ball.velocity
    if ball.pos.x < wallL.pos.x:
        ball.velocity.x = -ball.velocity.x
        varr.axis = vscale*ball.velocity
    
    if ball.pos.z < wallB.pos.z:
        ball.velocity.z = -ball.velocity.z
        varr.axis = vscale*ball.velocity
    
    if ball.pos.z > 6:
        ball.velocity.z = -ball.velocity.z
        varr.axis = vscale*ball.velocity
    
    if ball.pos.y < wallBottom.pos.y:
        ball.velocity.y = -ball.velocity.y
        varr.axis = vscale*ball.velocity
    if ball.pos.y > wallT.pos.y:
        ball.velocity.y = -ball.velocity.y
        varr.axis = vscale*ball.velocity
    
    ball.pos = ball.pos + ball.velocity*deltat
    varr.pos = ball.pos
    t = t + deltat
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# # Goals

# %% [markdown]
# a. What is your coding background?
# -I understand languages such as C/C++, Java, Python, and Matlab as per the COE Ciriculum. I also know how to apply code into embedded systems.
#
# b. What kind of software knowledge do you expect/want to get out of this course?
# -I want to undersad python more as it will probably what i will end up using for senior design. I won't have to worry about coding different languages
#
# c. What modeling and simulation concepts do you expect/want to learn about?
# -I would like to understand basic physics sim design as it is used pretty much in every stem field. The one I would like to know the most is Orbits as I would like to learn more about aerospace engineering in the future.
#
# d. What systems/domain areas are you interested in simulating (i.e., what systems
# would you find interesting as in-class simulation examples)?
# I would say anything involving probability as it would be neat to simulate something that doesn't always give you the right answer
